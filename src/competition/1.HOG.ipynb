# %% [markdown]
# # Histogram of Oriented Gradients

# %% [markdown]
# ## Data loading and preparation

# %%
#importing required libraries
from skimage.io import imread
from skimage.transform import resize
from skimage.feature import hog
from skimage import exposure
from scipy.spatial import distance
from sklearn.preprocessing import StandardScaler  # To transform the dataset
from sklearn.cluster import KMeans                # To instantiate, train and use model
from sklearn import metrics    
from scipy import spatial
import numpy as np
from numpy import dot
from numpy.linalg import norm
import os
import os.path
import time

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=False)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Unzipping the competition test dataset

# %%
# !unzip -q /content/drive/MyDrive/datasets/challenge_test_data.zip

# %%
GALLERY_PATH = "/content/gallery"
QUERY_PATH = "/content/query"

# %% [markdown]
# Defining a function to load images, transform them in black and white and resize them in a specific format.

# %%
def load_image(path):
    img = imread(path, plugin = "matplotlib", as_gray = True)
    resized_img = resize(img, (128, 64)) # HOG accepts only these dimensions
    return resized_img

# %% [markdown]
# ## Loading the images

# %%
image_extensions = ['.jpg', '.png', '.jpeg']   # case-insensitive (upper/lower doesn't matter)

gallery_images = [os.path.join(dp, f) for dp, dn, filenames in os.walk(GALLERY_PATH) for f in filenames if os.path.splitext(f)[1].lower() in image_extensions]
print("%d gallery images to analyze" % len(gallery_images))
# Out:
# 6355 gallery images to analyze

# %%
query_images = [os.path.join(dp, f) for dp, dn, filenames in os.walk(QUERY_PATH) for f in filenames if os.path.splitext(f)[1].lower() in image_extensions]
print("%d query images to analyze" % len(query_images))
# Out:
# 65 query images to analyze

# %% [markdown]
# ## Extracting the features from the images

# %% [markdown]
# To extract the feature vectors, we loop for each image and we do the extraction with the function hog, from the library scikit-image. Basically, it works like this:
# 1) The image is split in a series of 8x8 cells. Since it is a 128x64 image, we have 16x8 of such cells.
#
# 2) For each cell we compute the gradient (with magnitude and orientation) of each pixel.
#
# 3) We then create a histogram of 9 bins and we count the various gradients that go into each bin. The bins are 0-20°/20°-40°/.../160°-180°. Therefore, for each cell we end up with a 9-element vector corresponding to the values of each bin.
#
# 4) We define a block as a 2x2 window of cells. A block, therefore, is composed of a 36-element vector (9x4). We move this window with a stride = 1. This means that we will have a total of 7x15 possible blocks, each one with a 36-element vector.
#
# 5) Our final feature vector for each image will be then of length 7x15x36 = 3780
#
# We append each feature vector in the list query_features and gallery_features, respectively. They will be converted to numpy arrays.

# %%
tic = time.clock()
query_features = []
for i, image_path in enumerate(query_images):
    if i % 500 == 0:
        toc = time.clock()
        elap = toc-tic;
        print("analyzing image %d / %d. Time: %4.4f seconds." % (i, len(query_images),elap))
        tic = time.clock()
    img = load_image(image_path)
    fd, hog_image = hog(img, orientations=9, pixels_per_cell=(8, 8),
                      cells_per_block=(2, 2), visualize=True, multichannel=False)
    query_features.append(fd)
query_features = np.array(query_features)
print('finished extracting features for %d images' % len(query_images))

# %%
tic = time.clock()
gallery_features = []
for i, image_path in enumerate(gallery_images):
    if i % 500 == 0:
        toc = time.clock()
        elap = toc-tic;
        print("analyzing image %d / %d. Time: %4.4f seconds." % (i, len(gallery_images),elap))
        tic = time.clock()
    img = load_image(image_path)
    fd, hog_image = hog(img, orientations=9, pixels_per_cell=(8, 8),
                      cells_per_block=(2, 2), visualize=True, multichannel=False)
    gallery_features.append(fd)
gallery_features = np.array(gallery_features)
print('finished extracting features for %d images' % len(gallery_images))

# %% [markdown]
# ## Return similar images

# %% [markdown]
# We now define two function to return similar images, using both cosine distance and euclidean distance. We basically compute the difference according to these metrics between the query feature vector and all the gallery feature vectors. We find the closest images, we sort them and return the first 10.
# Then, since we want to return a dictionary, we create an ad-hoc function to do so.

# %%
def get_closest_images_cosine(query_image_idx, num_results=10):
    distances = [ distance.cosine(query_features[query_image_idx], feat) for feat in gallery_features]
    idx_closest = sorted(range(len(distances)), key=lambda k: distances[k])[:num_results]
    return idx_closest

def get_closest_images_euclidean(query_image_idx, num_results=10):
    distances = [ distance.euclidean(query_features[query_image_idx], feat) for feat in gallery_features]
    idx_closest = sorted(range(len(distances)), key=lambda k: distances[k])[:num_results]
    return idx_closest

# %%
def get_closest_dict(query_images, gallery_images, distance = 'cosine'):
  res = {}
  for i in range(len(query_images)):

    if distance == 'euclidean':
      idx_closest = get_closest_images_euclidean(i)
    else:
      idx_closest = get_closest_images_cosine(i)
      
    closest_images_list = [gallery_images[idx] for idx in idx_closest]
    res[query_images[i]] = closest_images_list

  return res

# %%
dizionario = get_closest_dict(query_images, gallery_images, 'euclidean')

# %%
from pprint import pprint
pprint(dizionario)
# Out:
# {'/content/query/013c80f43deff8d61b6a2021f9b0a335665fdd1f.jpg': ['/content/gallery/568a9dbbaaa534dbe3ff3129a15b70919d6b1909.jpg',
#                                                                  '/content/gallery/fa6bb036240952722af17b606851a91df0724f5b.jpg',
#                                                                  '/content/gallery/753604b63d559d50b074e802b81addb7510c1e09.jpg',
#                                                                  '/content/gallery/7e9738e35bda9222fdc76c62885d503e871e0ea6.jpg',
#                                                                  '/content/gallery/f9391118dd87c728cdc89d8754658a9ce28fdbec.jpg',
#                                                                  '/content/gallery/8947be7a0a18c4a3fa233e7c4276eaf424e28fcf.jpg',
#                                                                  '/content/gallery/d39ee97dfb9624c7d2666b73cf29bad8677cf9ef.jpg',
#                                                                  '/content/gallery/c5ccad62e76fcd8156957fad95249dd42024056f.jpg',
#                                                                  '/content/gallery/ae294ea4b121fb89525e06f9498a3692f284f457.jpg',
#                                                                  '/content/gallery/515b0785f53cda277774e191fe36d7dc7e022aaa.jpg'],
#  '/content/query/03ee85dcb5158552d2895d6d37effd2fad0fffde.jpg': ['/content/gallery/0f623677bf9a6c044bc1b03863ba10847bf0aca3.jpg',
#                                                                  '/content/gallery/fe2c6670a0f82be5b663ac7c71aee32ef4a7a4ae.jpg',
#                                                                  '/content/gallery/14c573617a558d91dcc53d187c3d91b5bad2fade.jpg',
#                                                                  '/content/gallery/014989fc67a7fd0dd286f9cfe5ffd9a3fb694c42.jpg',
#                                                                  '/content/gallery/c0319e72a62a497d4becb644059a1f98f14aa722.jpg',
#                                                                  '/content/gallery/a2f45e7eaf63cf15ebae1c852d2e35893164c6b7.jpg',
#                                                                  '/content/gallery/1f35b35b1400b72cedcfbdc597e8f86dcd7c0065.jpg',
#                                                                  '/content/gallery/209cf5052e344ddbf3b7b42a2165db9aacc0e6a4.jpg',
#                                                                  '/content/gallery/eaaa3353fe6ff8ff2b858fdf9ef9a15215c7c3f5.jpg',
#                                                                  '/content/gallery/4268e6248f3643dff1cbf6a3b71fb9e5436e5ae8.jpg'],
#  '/content/query/04769eb3b30f1926313d6ca6e8ad1c698af5007a.jpg': ['/content/gallery/acd4ccd2dff1555f08e007451d8f42f8c19f601e.jpg',
#                                                                  '/content/gallery/49a8bdab385146363eac9063040f2b519883de83.jpg',
#                                                                  '/content/gallery/e644b9232ff9e574c45f216ae632ced45f9782e6.jpg',
#                                                                  '/content/gallery/cf55086a0faecb3a6106d9740c20be5a04b3c497.jpg',
#                                                                  '/content/gallery/e178f2f689df5fcbe6ec9363dedb8f489899cb66.jpg',
#                                                                  '/content/gallery/03880f4243ee76339389a4d9ef103351d0667a32.jpg',
#                                                                  '/content/gallery/7e9738e35bda9222fdc76c62885d503e871e0ea6.jpg',
#                                                                  '/content/gallery/ff12d6be97037dbbb05f42ed074843c9927ef4d8.jpg',
#                                                                  '/content/gallery/0374c32944400b8064011f4f44fa346305836ab6.jpg',
#                                                                  '/content/gallery/56f698f5073d504f7a6167d4bb60d9e22a1ce635.jpg'],
#  '/content/query/107a5df0afa0c36f272ea7d01f14be2a66fb6b39.jpg': ['/content/gallery/3e25979e1e9e1186ded7692f9a96c870aa881634.jpg',
#                                                                  '/content/gallery/654614d01d14f00c221f56f1192c123098b57a38.jpg',
#                                                                  '/content/gallery/315a88e5b673c042d343226c48f77bf82e998a26.jpg',
#                                                                  '/content/gallery/20430a8544cc87799abd2c1f79846b0c79eece83.jpg',
#                                                                  '/content/gallery/91cc47a2ac6f2cb03cff2244856017400fbf0383.jpg',
#                                                                  '/content/gallery/38e4a2e574085ec26d76fcb97221400f60aa10ac.jpg',
#                                                                  '/content/gallery/80f08f6f374d0b4aa7dd44b2c65c31617e2bfd45.jpg',
#                                                                  '/content/gallery/ccae2ccb84986c593756c0d8a35557055c42af09.jpg',
#                                                                  '/content/gallery/5514956d4976b2cf70854a874d786ca31eeb0578.jpg',
#                                                                  '/content/gallery/7e9738e35bda9222fdc76c62885d503e871e0ea6.jpg'],
#  '/content/query/195ca6ff91f8e6ab0fee2a0bd8dd77e662605ef5.jpg': ['/content/gallery/82944e6cfe82634bad3dc1d7ab01e63730671074.jpg',
#                                                                  '/content/gallery/81aa98c4fb413450df484b041b2e88a6f86cd243.jpg',
#                                                                  '/content/gallery/478b39e95997c9ae79e08bfb7eee529443045cd7.jpg',
#                                                                  '/content/gallery/8f6c9c4afb9eab460be1eb557dc176dc1234e1b8.jpg',
#                                                                  '/content/gallery/c88c0f35cb08bfac8be43a53fcc672e2b26a7945.jpg',
#                                                                  '/content/gallery/6e3d435f10a94d95be9f18f69336ffc3ab678ad5.jpg',
#                                                                  '/content/gallery/0606866a6b8b14e4ed2ef1df056d74434357cc52.jpg',
#                                                                  '/content/gallery/bcc9903011c4805087c8cb468bdb4f562360fef0.jpg',
#                                                                  '/content/gallery/49a8bdab385146363eac9063040f2b519883de83.jpg',
#                                                                  '/content/gallery/ae3b46edc7b89ab3c8ae0717d12998d6c5aa7348.jpg'],
#  '/content/query/1b21fc4e5ab4419b11411cc44a6234ab9c7ecefe.jpg': ['/content/gallery/f6024402a7c84ff4f9048c7a19a335e4a1c86812.jpg',
#                                                                  '/content/gallery/7aa5b6a00cea3370acc1cee120e1a8fcad86a145.jpg',
#                                                                  '/content/gallery/9451b3ed390e80834c7d7410bc5141c866d056e1.jpg',
#                                                                  '/content/gallery/f103913eb59e5d3143417ac06021a095ab49ab3a.jpg',
#                                                                  '/content/gallery/83f3942d8530abb9f41494458b04bd87692a4963.jpg',
#                                                                  '/content/gallery/6df0c8f736f583aa6290164af5c8c2d5852a30df.jpg',
#                                                                  '/content/gallery/75b315a4f3f737984295f9237405f7a4f51b9698.jpg',
#                                                                  '/content/gallery/f608562e8d1b6ffe7468225b327275dd6ca9e45e.jpg',
#                                                                  '/content/gallery/56f698f5073d504f7a6167d4bb60d9e22a1ce635.jpg',
#                                                                  '/content/gallery/120365695a5080e6b4643bea93bb0d5acf15f98c.jpg'],
#  '/content/query/1c16dc110f78c763c3803c599dc14331da0c7294.jpg': ['/content/gallery/fa2680718f714c3c9ca5534a62160f5dd1f14c89.jpg',
#                                                                  '/content/gallery/92c5b7cc1947358768032bb5389da2e6cee3dcdd.jpg',
#                                                                  '/content/gallery/7e9738e35bda9222fdc76c62885d503e871e0ea6.jpg',
#                                                                  '/content/gallery/9838124c328cffa75b522a935e18b7cbaf693bc9.jpg',
#                                                                  '/content/gallery/47a75afa8203025251b749fe553ec90973763023.jpg',
#                                                                  '/content/gallery/a89db4077121cddd5c4230dc9ba62a5f5765373b.jpg',
#                                                                  '/content/gallery/17f4b66095c9d49e64914b6f0dc4fc674c7c25f2.jpg',
#                                                                  '/content/gallery/56f698f5073d504f7a6167d4bb60d9e22a1ce635.jpg',
#                                                                  '/content/gallery/03880f4243ee76339389a4d9ef103351d0667a32.jpg',
#                                                                  '/content/gallery/e7769d2fac0a254619fd672faf8023d869a6484b.jpg'],
#  '/content/query/245711a4ebf210d031fc6321e990d1bc6ef8efa8.jpg': ['/content/gallery/eb95e92de4ece9b0893cb50f34b215b030cf3e08.jpg',
#                                                                  '/content/gallery/dd488da55f51f7b4fd628882e0286391f5ba47d8.jpg',
#                                                                  '/content/gallery/a4a385a2a465ae69241fc6b944adec060dfed1c3.jpg',
#                                                                  '/content/gallery/40a48ee2cef269d78b0a730030f3d02b9dc606aa.jpg',
#                                                                  '/content/gallery/9845925491eb0f0a4ca364e49d9b5360288664f4.jpg',
#                                                                  '/content/gallery/e8965ad846391c15ce36feeec944e786d38d1f78.jpg',
#                                                                  '/content/gallery/56f698f5073d504f7a6167d4bb60d9e22a1ce635.jpg',
#                                                                  '/content/gallery/bbc968b450ad016155c02ed84afd24109303aee4.jpg',
#                                                                  '/content/gallery/668f73760e272d56a14dd2b3461d4ef05b7f1a0c.jpg',
#                                                                  '/content/gallery/3e9446c480d28d0f78ce2ef5132c2d36981f2fd2.jpg'],
#  '/content/query/249596e6667871531f8c3409be363560d82f958f.jpg': ['/content/gallery/967370b8d81249b80975be5ed25b0cc8d9dc793a.jpg',
#                                                                  '/content/gallery/17f4b66095c9d49e64914b6f0dc4fc674c7c25f2.jpg',
#                                                                  '/content/gallery/81aa98c4fb413450df484b041b2e88a6f86cd243.jpg',
#                                                                  '/content/gallery/c88c0f35cb08bfac8be43a53fcc672e2b26a7945.jpg',
#                                                                  '/content/gallery/b5f34c0a5443c221ffabff035ccb9954ee8f0dc8.jpg',
#                                                                  '/content/gallery/a15d0fda127f1d992dbb7518e8f318217070ad62.jpg',
#                                                                  '/content/gallery/b5bee120ca9f126d15b8d2e876019262184e3e0e.jpg',
#                                                                  '/content/gallery/e3d955c4cad0111ce3c7705d7333ccd1778a95a6.jpg',
#                                                                  '/content/gallery/8f6c9c4afb9eab460be1eb557dc176dc1234e1b8.jpg',
#                                                                  '/content/gallery/e7d879812455b39cf06fb7c248faab4b63181472.jpg'],
#  '/content/query/27ca33fe84d536a7610ed5d9c03b757ae0ddac95.jpg': ['/content/gallery/7e9738e35bda9222fdc76c62885d503e871e0ea6.jpg',
#                                                                  '/content/gallery/2f4ae1c1d785c8f893be2d444fbf682f43c5e182.jpg',
#                                                                  '/content/gallery/668f73760e272d56a14dd2b3461d4ef05b7f1a0c.jpg',
#                                                                  '/content/gallery/cba5174ea4fbc7ff7c95c0f8f129e095acb70581.jpg',
#                                                                  '/content/gallery/b6e8660776ee0fcfe137af3b44421d1fa236d155.jpg',
#                                                                  '/content/gallery/891a185cf4f69c9bafc4ab6a69c662af0384ae82.jpg',
#                                                                  '/content/gallery/a89db4077121cddd5c4230dc9ba62a5f5765373b.jpg',
#                                                                  '/content/gallery/92d5ba3fa38c3072a90d101ab389fbbaffb0da49.jpg',
#                                                                  '/content/gallery/fa2680718f714c3c9ca5534a62160f5dd1f14c89.jpg',
#                                                                  '/content/gallery/49a8bdab385146363eac9063040f2b519883de83.jpg'],
#  '/content/query/2bc4aad7e5e3ff47c06af95854280fce9cfc6390.jpg': ['/content/gallery/891a185cf4f69c9bafc4ab6a69c662af0384ae82.jpg',
#                                                                  '/content/gallery/cc0b0944c93703877f51e8af38c6ecc5c0799326.jpg',
#                                                                  '/content/gallery/49a8bdab385146363eac9063040f2b519883de83.jpg',
#                                                                  '/content/gallery/75b315a4f3f737984295f9237405f7a4f51b9698.jpg',
#                                                                  '/content/gallery/e644b9232ff9e574c45f216ae632ced45f9782e6.jpg',
#                                                                  '/content/gallery/e786232ad0da604d1e948558e32bec9a0431c6c2.jpg',
#                                                                  '/content/gallery/c109127c2d00253ff2183a8235452e579d0bb488.jpg',
#                                                                  '/content/gallery/03b091e53877d819e5778a48701b1f6d74f468af.jpg',
#                                                                  '/content/gallery/a15d0fda127f1d992dbb7518e8f318217070ad62.jpg',
#                                                                  '/content/gallery/023ea30c3beaf50b22b03b73bdb51b5e6ba7bdd7.jpg'],
#  '/content/query/3367cfef107910dc4846f5c53176c9984198e923.jpg': ['/content/gallery/b5f34c0a5443c221ffabff035ccb9954ee8f0dc8.jpg',
#                                                                  '/content/gallery/364fff5544e1d33c870e0f53564de448bcb07ca1.jpg',
#                                                                  '/content/gallery/69c592be98a8aeb73f5fed423e586cac3eab342a.jpg',
#                                                                  '/content/gallery/0e43b92a9a20ed006610574557afcd25a2ee4db7.jpg',
#                                                                  '/content/gallery/b5bee120ca9f126d15b8d2e876019262184e3e0e.jpg',
#                                                                  '/content/gallery/9208730495d673506b4e99bd89b0a206294cbffc.jpg',
#                                                                  '/content/gallery/83f3942d8530abb9f41494458b04bd87692a4963.jpg',
#                                                                  '/content/gallery/023ea30c3beaf50b22b03b73bdb51b5e6ba7bdd7.jpg',
#                                                                  '/content/gallery/8f6c9c4afb9eab460be1eb557dc176dc1234e1b8.jpg',
#                                                                  '/content/gallery/108174261a571a6a8e32f20e19f3921027fa2e1e.jpg'],
#  '/content/query/3e759d812ed8189387b35f630ed71ff6c5064dc6.jpg': ['/content/gallery/b5bee120ca9f126d15b8d2e876019262184e3e0e.jpg',
#                                                                  '/content/gallery/8f6c9c4afb9eab460be1eb557dc176dc1234e1b8.jpg',
#                                                                  '/content/gallery/17f4b66095c9d49e64914b6f0dc4fc674c7c25f2.jpg',
#                                                                  '/content/gallery/21a8796098d27201e7766b85cb2942d691ceeb11.jpg',
#                                                                  '/content/gallery/967370b8d81249b80975be5ed25b0cc8d9dc793a.jpg',
#                                                                  '/content/gallery/81aa98c4fb413450df484b041b2e88a6f86cd243.jpg',
#                                                                  '/content/gallery/29b0eaa2b2f1648a871bd1c2b11226b3e20db5d3.jpg',
#                                                                  '/content/gallery/0c4fa7d0afe74ad7d99e3c80a387be776e5acac3.jpg',
#                                                                  '/content/gallery/478b39e95997c9ae79e08bfb7eee529443045cd7.jpg',
#                                                                  '/content/gallery/3f5477c841680194bf74e4021e2b0c582bbba12a.jpg'],
#  '/content/query/3ff3f6687e676164720e20202ca9079cf6380c89.jpg': ['/content/gallery/1bc11614fc3f0bb418f8de4305797efeb26a2070.jpg',
#                                                                  '/content/gallery/af06f2f4711b902c6a29ee92473eabcd12eb56db.jpg',
#                                                                  '/content/gallery/20e2da7c3736d1e434fa10b63a768650e46b28d5.jpg',
#                                                                  '/content/gallery/3932c97321bb61b80ded4af8752b9682f65c1b8e.jpg',
#                                                                  '/content/gallery/0ace339f8176b5cffdbdf2a188f17c9d721b9556.jpg',
#                                                                  '/content/gallery/8794b07a06107ee7f2c7c18f901bc88ea5a70a02.jpg',
#                                                                  '/content/gallery/ebd103da14edcfa89ab1f1429fcb4565cf9e48a6.jpg',
#                                                                  '/content/gallery/8fb155bc8c18270e7221b7bb70b10145c530d248.jpg',
#                                                                  '/content/gallery/0f4af31f2ee33c665aeeecb3272f2d65741327a6.jpg',
#                                                                  '/content/gallery/0b549c9a652b185aa407694757dec7a16b29f4c8.jpg'],
#  '/content/query/405c554c7663293ebf309f38e2407ad4d5fdf2e4.jpg': ['/content/gallery/59dcf327925a84c5af3ec8aafa6b1867edde7229.jpg',
#                                                                  '/content/gallery/20430a8544cc87799abd2c1f79846b0c79eece83.jpg',
#                                                                  '/content/gallery/23fcc8d81233f23b0f798c7c14c87a5f6cb1ceed.jpg',
#                                                                  '/content/gallery/dc2ec3366f751b38353f17cdede0788b074dcd23.jpg',
#                                                                  '/content/gallery/b3dee05fad2253037b747e080c29f0b41ac256a0.jpg',
#                                                                  '/content/gallery/d76e83d2dbfc0b80e4b2429140d12e13bceb81fa.jpg',
#                                                                  '/content/gallery/6da6fc5f7db9564cf3ff726f463cb95844e217d5.jpg',
#                                                                  '/content/gallery/ccae2ccb84986c593756c0d8a35557055c42af09.jpg',
#                                                                  '/content/gallery/1cfa965fd2fbb24e734bad2015ebc0533f74722f.jpg',
#                                                                  '/content/gallery/19ee0483f60336992299eca3ffeb1d1a889511a3.jpg'],
#  '/content/query/40aecaa7aa88e15616b93dc95528393f693d9a04.jpg': ['/content/gallery/b5bee120ca9f126d15b8d2e876019262184e3e0e.jpg',
#                                                                  '/content/gallery/92d5ba3fa38c3072a90d101ab389fbbaffb0da49.jpg',
#                                                                  '/content/gallery/acd4ccd2dff1555f08e007451d8f42f8c19f601e.jpg',
#                                                                  '/content/gallery/891a185cf4f69c9bafc4ab6a69c662af0384ae82.jpg',
#                                                                  '/content/gallery/a15d0fda127f1d992dbb7518e8f318217070ad62.jpg',
#                                                                  '/content/gallery/56f698f5073d504f7a6167d4bb60d9e22a1ce635.jpg',
#                                                                  '/content/gallery/2f4ae1c1d785c8f893be2d444fbf682f43c5e182.jpg',
#                                                                  '/content/gallery/cba5174ea4fbc7ff7c95c0f8f129e095acb70581.jpg',
#                                                                  '/content/gallery/668f73760e272d56a14dd2b3461d4ef05b7f1a0c.jpg',
#                                                                  '/content/gallery/44c75027ccebab6236df08d3f79666fabc44f8bc.jpg'],
#  '/content/query/43003c5db455cd8476296d04cc9ce58fae5c9088.jpg': ['/content/gallery/668f73760e272d56a14dd2b3461d4ef05b7f1a0c.jpg',
#                                                                  '/content/gallery/2f4ae1c1d785c8f893be2d444fbf682f43c5e182.jpg',
#                                                                  '/content/gallery/49a8bdab385146363eac9063040f2b519883de83.jpg',
#                                                                  '/content/gallery/f9b26165ba2f14d518849029c4937955c9ede28d.jpg',
#                                                                  '/content/gallery/b5bee120ca9f126d15b8d2e876019262184e3e0e.jpg',
#                                                                  '/content/gallery/acd4ccd2dff1555f08e007451d8f42f8c19f601e.jpg',
#                                                                  '/content/gallery/ae294ea4b121fb89525e06f9498a3692f284f457.jpg',
#                                                                  '/content/gallery/8947be7a0a18c4a3fa233e7c4276eaf424e28fcf.jpg',
#                                                                  '/content/gallery/3e9446c480d28d0f78ce2ef5132c2d36981f2fd2.jpg',
#                                                                  '/content/gallery/6a3bd4649faf1eabff60e6067a654b1404649d9d.jpg'],
#  '/content/query/4a7fd43826a00989999991693b2b993b74b6fc23.jpg': ['/content/gallery/d8b8e862229b2b3c8d89ba7ec54d2b5a58268fae.jpg',
#                                                                  '/content/gallery/3f5477c841680194bf74e4021e2b0c582bbba12a.jpg',
#                                                                  '/content/gallery/34816467f9652d03eb1dadd188f474922f5eb1ae.jpg',
#                                                                  '/content/gallery/16ae1b408b572936aa2a43c1b774b8cb6797abf3.jpg',
#                                                                  '/content/gallery/72648d7c0c68dd02532c3168a9ebf8ddf84d4c63.jpg',
#                                                                  '/content/gallery/d27dcd4bc890acb92f2314b1c39f64b5b580d3a6.jpg',
#                                                                  '/content/gallery/635400351bb2ceeb03f174bd91574246ba97fd25.jpg',
#                                                                  '/content/gallery/6b43221fb2eb6b500cef10c19d15b87f79e5e809.jpg',
#                                                                  '/content/gallery/3fcdcc623e3981e7af7e7d1422651af7d0f64a14.jpg',
#                                                                  '/content/gallery/00c203ab894d98c0825b922e34472277f6b99ed6.jpg'],
#  '/content/query/4f23d0fe9f14c38007f383e3ce0036e2a2eaebf5.jpg': ['/content/gallery/1a436e021c115a293c9265d007de6eaaebf679c1.jpg',
#                                                                  '/content/gallery/0c8e251938c98972e6e7401a935e121a07720530.jpg',
#                                                                  '/content/gallery/97999eff3fdcd91b6c39deab44223e7307fe6202.jpg',
#                                                                  '/content/gallery/c44d0f1e0b301ef7e11731c6359995dcad8089bf.jpg',
#                                                                  '/content/gallery/1bc11614fc3f0bb418f8de4305797efeb26a2070.jpg',
#                                                                  '/content/gallery/af06f2f4711b902c6a29ee92473eabcd12eb56db.jpg',
#                                                                  '/content/gallery/20e2da7c3736d1e434fa10b63a768650e46b28d5.jpg',
#                                                                  '/content/gallery/3932c97321bb61b80ded4af8752b9682f65c1b8e.jpg',
#                                                                  '/content/gallery/0ace339f8176b5cffdbdf2a188f17c9d721b9556.jpg',
#                                                                  '/content/gallery/f147d63da22e9c9597d3898d897b796b1e66adf8.jpg'],
#  '/content/query/54a7087e39b0c41c3c9545133939c0cb40ee3a25.jpg': ['/content/gallery/4e9800c3ccbdbbed538f9e3cc10bc9d955720f6a.jpg',
#                                                                  '/content/gallery/6da6fc5f7db9564cf3ff726f463cb95844e217d5.jpg',
#                                                                  '/content/gallery/03b091e53877d819e5778a48701b1f6d74f468af.jpg',
#                                                                  '/content/gallery/6df0c8f736f583aa6290164af5c8c2d5852a30df.jpg',
#                                                                  '/content/gallery/120365695a5080e6b4643bea93bb0d5acf15f98c.jpg',
#                                                                  '/content/gallery/92c5b7cc1947358768032bb5389da2e6cee3dcdd.jpg',
#                                                                  '/content/gallery/7e9738e35bda9222fdc76c62885d503e871e0ea6.jpg',
#                                                                  '/content/gallery/3722c591593df5f2271508f1228a14d43041c520.jpg',
#                                                                  '/content/gallery/209cf5052e344ddbf3b7b42a2165db9aacc0e6a4.jpg',
#                                                                  '/content/gallery/23fcc8d81233f23b0f798c7c14c87a5f6cb1ceed.jpg'],
#  '/content/query/58477d99b16ad211d53ffb3f5b6a49279695d0e4.jpg': ['/content/gallery/7e9738e35bda9222fdc76c62885d503e871e0ea6.jpg',
#                                                                  '/content/gallery/a600b5196e8486d5d25e7689f3c68fe98c416171.jpg',
#                                                                  '/content/gallery/03b091e53877d819e5778a48701b1f6d74f468af.jpg',
#                                                                  '/content/gallery/bc9133f4b16616ea8420118bb185cfa0bfa87534.jpg',
#                                                                  '/content/gallery/3e00c67cbe139f06466b836454104072f0aacd8e.jpg',
#                                                                  '/content/gallery/30d36d57daacb97a5653a779dee3a517d8013e98.jpg',
#                                                                  '/content/gallery/afefc5537efe71143c6010d195cade8c15aa0e37.jpg',
#                                                                  '/content/gallery/6da6fc5f7db9564cf3ff726f463cb95844e217d5.jpg',
#                                                                  '/content/gallery/891a185cf4f69c9bafc4ab6a69c662af0384ae82.jpg',
#                                                                  '/content/gallery/dc2ec3366f751b38353f17cdede0788b074dcd23.jpg'],
#  '/content/query/5bbb6a121ff7f051a00ac21f83e17203e6648a93.jpg': ['/content/gallery/8f6c9c4afb9eab460be1eb557dc176dc1234e1b8.jpg',
#                                                                  '/content/gallery/17f4b66095c9d49e64914b6f0dc4fc674c7c25f2.jpg',
#                                                                  '/content/gallery/a4a47630d69ec8c6acf1eb45c6085e965540cc53.jpg',
#                                                                  '/content/gallery/9208730495d673506b4e99bd89b0a206294cbffc.jpg',
#                                                                  '/content/gallery/c6e2f82cf0de7a9386b3ba55adfd61f3637ebe35.jpg',
#                                                                  '/content/gallery/fa6bb036240952722af17b606851a91df0724f5b.jpg',
#                                                                  '/content/gallery/39fff54c8a614ed171a827844f593c9f9fa5c09a.jpg',
#                                                                  '/content/gallery/3300db03063be86c6f3f4e3f95dad3b3d56cd6ac.jpg',
#                                                                  '/content/gallery/b5bee120ca9f126d15b8d2e876019262184e3e0e.jpg',
#                                                                  '/content/gallery/dad6e7d5b99cd3398f0388fc06237383b6d2baa6.jpg'],
#  '/content/query/5c0fdd616fd38980cb359af8d375ce00670fba48.jpg': ['/content/gallery/2eebeb5ee89f04500c8ccacda70e790d43317fd0.jpg',
#                                                                  '/content/gallery/4c010a49c976a6b8a4b3a6a340ebbfc04b5b1dd9.jpg',
#                                                                  '/content/gallery/f1b399e44bb970ca190efc6d2f3d32362c5d73e8.jpg',
#                                                                  '/content/gallery/2e1a2d0b5a2a1e0d26377a6795a017b54fc96a84.jpg',
#                                                                  '/content/gallery/fa6bb036240952722af17b606851a91df0724f5b.jpg',
#                                                                  '/content/gallery/2b1aa8f7b3f46cf3cebdbf889ba038fae50cb2aa.jpg',
#                                                                  '/content/gallery/ecd2c29f031075e86794b4b025b8cd49f6381e65.jpg',
#                                                                  '/content/gallery/7129ef29c9700d6275a2ca8d93f0ba39b60696ab.jpg',
#                                                                  '/content/gallery/34816467f9652d03eb1dadd188f474922f5eb1ae.jpg',
#                                                                  '/content/gallery/83f3942d8530abb9f41494458b04bd87692a4963.jpg'],
#  '/content/query/5faad851ca894625e9bd69b43f87fd28a6703aec.jpg': ['/content/gallery/5e5106694a0f9df042a3be18b8ee8544979c7a16.jpg',
#                                                                  '/content/gallery/11783935cf29947be85567d85077964455f58ddf.jpg',
#                                                                  '/content/gallery/33f10c280ed00dc8817af2e7faa8d4f40e9827fc.jpg',
#                                                                  '/content/gallery/11500bdd23d0753e2679d848569495e49414d4aa.jpg',
#                                                                  '/content/gallery/d9be267d846b5a034aeb4285487c50ef2e4365af.jpg',
#                                                                  '/content/gallery/17b84e23c02a708e231e9390cc585651fc95cdcd.jpg',
#                                                                  '/content/gallery/635400351bb2ceeb03f174bd91574246ba97fd25.jpg',
#                                                                  '/content/gallery/68cdf5fc543f2f793394e899bda13850ee9de697.jpg',
#                                                                  '/content/gallery/38e4a2e574085ec26d76fcb97221400f60aa10ac.jpg',
#                                                                  '/content/gallery/9cd1819abc03ab6dd21526975462e66cb6224b8c.jpg'],
#  '/content/query/68d1f5b234d3bd015aaa307537a64fcba577cfab.jpg': ['/content/gallery/a533b7561151813033796b76fa40c27a55789a2b.jpg',
#                                                                  '/content/gallery/4d96df37824dc7e43bc500099d2b7c50c848b5fc.jpg',
#                                                                  '/content/gallery/92c5b7cc1947358768032bb5389da2e6cee3dcdd.jpg',
#                                                                  '/content/gallery/fbdd739f9bc1f621508380924e4ae5912c61cec9.jpg',
#                                                                  '/content/gallery/af28fbd8de009f03c523d0803fdd64d77c3642d4.jpg',
#                                                                  '/content/gallery/20430a8544cc87799abd2c1f79846b0c79eece83.jpg',
#                                                                  '/content/gallery/3722c591593df5f2271508f1228a14d43041c520.jpg',
#                                                                  '/content/gallery/28a006050b2259b121d0a32ee4aeb295f4d632a6.jpg',
#                                                                  '/content/gallery/03b091e53877d819e5778a48701b1f6d74f468af.jpg',
#                                                                  '/content/gallery/42b241aa67f232343ecb62801db6e4caa3461113.jpg'],
#  '/content/query/6b3aee4bdb8c8ad996e93e0509e03299e56ab1d4.jpg': ['/content/gallery/1935cf61d55195f43aebd5f07d0b18819b7da771.jpg',
#                                                                  '/content/gallery/02cbb63862243c5ed220e1b3b0eba5a855294fa6.jpg',
#                                                                  '/content/gallery/aa674e73a6b7113b33926ae96ba0c8435a1988be.jpg',
#                                                                  '/content/gallery/b8a92d0405550cd5f14bc336eec2410a3d7b77d8.jpg',
#                                                                  '/content/gallery/0d6a570806da13b5d336d224e1489240216ec1c3.jpg',
#                                                                  '/content/gallery/0838c1619a7a9843085e8bab4e23b99123887939.jpg',
#                                                                  '/content/gallery/74c2be728e8708ba64856d7312f1769b0953cb33.jpg',
#                                                                  '/content/gallery/65987369856f1bce4ac21a7d277d8bb00bfa7668.jpg',
#                                                                  '/content/gallery/2f4ae1c1d785c8f893be2d444fbf682f43c5e182.jpg',
#                                                                  '/content/gallery/bcc9903011c4805087c8cb468bdb4f562360fef0.jpg'],
#  '/content/query/6e327e9d90187609fac360e0702ae6e7a9b66a84.jpg': ['/content/gallery/7e9738e35bda9222fdc76c62885d503e871e0ea6.jpg',
#                                                                  '/content/gallery/fa2680718f714c3c9ca5534a62160f5dd1f14c89.jpg',
#                                                                  '/content/gallery/92c5b7cc1947358768032bb5389da2e6cee3dcdd.jpg',
#                                                                  '/content/gallery/72b6475dba5f69f3d73c8698fac6c9b7773f200c.jpg',
#                                                                  '/content/gallery/a89db4077121cddd5c4230dc9ba62a5f5765373b.jpg',
#                                                                  '/content/gallery/56f698f5073d504f7a6167d4bb60d9e22a1ce635.jpg',
#                                                                  '/content/gallery/49a8bdab385146363eac9063040f2b519883de83.jpg',
#                                                                  '/content/gallery/2f4ae1c1d785c8f893be2d444fbf682f43c5e182.jpg',
#                                                                  '/content/gallery/75b315a4f3f737984295f9237405f7a4f51b9698.jpg',
#                                                                  '/content/gallery/e644b9232ff9e574c45f216ae632ced45f9782e6.jpg'],
#  '/content/query/75dd73521d157440c11c15cadcaac043f0deed04.jpg': ['/content/gallery/20430a8544cc87799abd2c1f79846b0c79eece83.jpg',
#                                                                  '/content/gallery/03b091e53877d819e5778a48701b1f6d74f468af.jpg',
#                                                                  '/content/gallery/7e9738e35bda9222fdc76c62885d503e871e0ea6.jpg',
#                                                                  '/content/gallery/ccae2ccb84986c593756c0d8a35557055c42af09.jpg',
#                                                                  '/content/gallery/120365695a5080e6b4643bea93bb0d5acf15f98c.jpg',
#                                                                  '/content/gallery/30d36d57daacb97a5653a779dee3a517d8013e98.jpg',
#                                                                  '/content/gallery/75b315a4f3f737984295f9237405f7a4f51b9698.jpg',
#                                                                  '/content/gallery/cba5174ea4fbc7ff7c95c0f8f129e095acb70581.jpg',
#                                                                  '/content/gallery/49a8bdab385146363eac9063040f2b519883de83.jpg',
#                                                                  '/content/gallery/654614d01d14f00c221f56f1192c123098b57a38.jpg'],
#  '/content/query/838da29d088ed3a2894b26ab46384eadfbd46c90.jpg': ['/content/gallery/9e0ca6a82477023a5837cf00dee01b4fc8c8bd44.jpg',
#                                                                  '/content/gallery/120365695a5080e6b4643bea93bb0d5acf15f98c.jpg',
#                                                                  '/content/gallery/c109127c2d00253ff2183a8235452e579d0bb488.jpg',
#                                                                  '/content/gallery/23fcc8d81233f23b0f798c7c14c87a5f6cb1ceed.jpg',
#                                                                  '/content/gallery/4ee3cf0959f29313be19c4d9ab94f3fae3d12e24.jpg',
#                                                                  '/content/gallery/b83e5904ee29da33dcc267de13ffea3de22f7bca.jpg',
#                                                                  '/content/gallery/e655740b5f551bf2276de6b8390526584b895d7a.jpg',
#                                                                  '/content/gallery/6da6fc5f7db9564cf3ff726f463cb95844e217d5.jpg',
#                                                                  '/content/gallery/92c5b7cc1947358768032bb5389da2e6cee3dcdd.jpg',
#                                                                  '/content/gallery/11500bdd23d0753e2679d848569495e49414d4aa.jpg'],
#  '/content/query/86bc5acb40a7e733316a7a2c957ff9c9b507c8b6.jpg': ['/content/gallery/9ccc53574e27e8bc1add2785969885e4654596bb.jpg',
#                                                                  '/content/gallery/83f3942d8530abb9f41494458b04bd87692a4963.jpg',
#                                                                  '/content/gallery/b4bc08c6618c970754ad9eb5b5699ca392c63f46.jpg',
#                                                                  '/content/gallery/81aa98c4fb413450df484b041b2e88a6f86cd243.jpg',
#                                                                  '/content/gallery/12d0ccba8087feeabc7badae31347c0c0aebe4c0.jpg',
#                                                                  '/content/gallery/db1a30f206f25dafe3ca4127991d61541206ef37.jpg',
#                                                                  '/content/gallery/b5bee120ca9f126d15b8d2e876019262184e3e0e.jpg',
#                                                                  '/content/gallery/8f6c9c4afb9eab460be1eb557dc176dc1234e1b8.jpg',
#                                                                  '/content/gallery/cf55086a0faecb3a6106d9740c20be5a04b3c497.jpg',
#                                                                  '/content/gallery/4e9800c3ccbdbbed538f9e3cc10bc9d955720f6a.jpg'],
#  '/content/query/8852789966dfafec19c2b4b2275b167fdd006c9e.jpg': ['/content/gallery/5d662ef67fd02e577b08ecd5d1265c5a2909feb2.jpg',
#                                                                  '/content/gallery/4eb8ea9ec82e26e8997d8b7189c4e8234750bb49.jpg',
#                                                                  '/content/gallery/91512bdb875347bbdfbbd34958172e012e36117f.jpg',
#                                                                  '/content/gallery/845d57e04ec86c2cf82da91ccbfab4b8add3b224.jpg',
#                                                                  '/content/gallery/2e4ae6b4faad33ed02694e1ce6f429c8352b04df.jpg',
#                                                                  '/content/gallery/28c3175087e6d4792ddbd532d8e98135133b3fd4.jpg',
#                                                                  '/content/gallery/ce17eaf844673e1a9852d1783dffcbc006783385.jpg',
#                                                                  '/content/gallery/22b44c24c843ccefe9f8712eb51c79abe8baf1e0.jpg',
#                                                                  '/content/gallery/9630bc7aa7fa9ab9c11863d7045d365be643cb0f.jpg',
#                                                                  '/content/gallery/ac23843ea2bb1f08a12be1051bd94ccb3d807fc7.jpg'],
#  '/content/query/88fb01eca2ba625d4942bf8a2c0c87bddb2cffea.jpg': ['/content/gallery/23fcc8d81233f23b0f798c7c14c87a5f6cb1ceed.jpg',
#                                                                  '/content/gallery/59dcf327925a84c5af3ec8aafa6b1867edde7229.jpg',
#                                                                  '/content/gallery/bf9eeb9b6570ad7dd9af6787ff1941c0dabd1d1f.jpg',
#                                                                  '/content/gallery/790f4956defe7fe9cba36390c7c354c2ce2fec8d.jpg',
#                                                                  '/content/gallery/9d5ddec1dae98fab445c525e31c073b8df8e385b.jpg',
#                                                                  '/content/gallery/c71c8b71d6038a323e10b8e15e34dbbceca15540.jpg',
#                                                                  '/content/gallery/2c3b5589cffd90f234fb4ec8951027cd8d5f1492.jpg',
#                                                                  '/content/gallery/04131f90d82d8a8fe4a95c6a87a884eb182ad337.jpg',
#                                                                  '/content/gallery/ae5108417e160b161558f811284a9235f692f0d6.jpg',
#                                                                  '/content/gallery/e83029ee84de4ca4ef88c42940cbcea7318d7355.jpg'],
#  '/content/query/8df564518f6f2e53481ead317ce71fde73d604f3.jpg': ['/content/gallery/f0f3126f7fd4cd77e68e47dcf3f79592849c44a8.jpg',
#                                                                  '/content/gallery/49a8bdab385146363eac9063040f2b519883de83.jpg',
#                                                                  '/content/gallery/2d600c4f3bef82d1c9b473c80b3c007d0683914d.jpg',
#                                                                  '/content/gallery/00c203ab894d98c0825b922e34472277f6b99ed6.jpg',
#                                                                  '/content/gallery/fa2680718f714c3c9ca5534a62160f5dd1f14c89.jpg',
#                                                                  '/content/gallery/c88c0f35cb08bfac8be43a53fcc672e2b26a7945.jpg',
#                                                                  '/content/gallery/c6e2f82cf0de7a9386b3ba55adfd61f3637ebe35.jpg',
#                                                                  '/content/gallery/ae3b46edc7b89ab3c8ae0717d12998d6c5aa7348.jpg',
#                                                                  '/content/gallery/56f698f5073d504f7a6167d4bb60d9e22a1ce635.jpg',
#                                                                  '/content/gallery/acd4ccd2dff1555f08e007451d8f42f8c19f601e.jpg'],
#  '/content/query/8e4732fd6f29515f07c660c66a735ad865e29460.jpg': ['/content/gallery/2f4ae1c1d785c8f893be2d444fbf682f43c5e182.jpg',
#                                                                  '/content/gallery/7e9738e35bda9222fdc76c62885d503e871e0ea6.jpg',
#                                                                  '/content/gallery/120365695a5080e6b4643bea93bb0d5acf15f98c.jpg',
#                                                                  '/content/gallery/e644b9232ff9e574c45f216ae632ced45f9782e6.jpg',
#                                                                  '/content/gallery/56f698f5073d504f7a6167d4bb60d9e22a1ce635.jpg',
#                                                                  '/content/gallery/fa2680718f714c3c9ca5534a62160f5dd1f14c89.jpg',
#                                                                  '/content/gallery/ae3b46edc7b89ab3c8ae0717d12998d6c5aa7348.jpg',
#                                                                  '/content/gallery/32d24aae59e9c96d1010ed424625eda2b8f0016f.jpg',
#                                                                  '/content/gallery/cba5174ea4fbc7ff7c95c0f8f129e095acb70581.jpg',
#                                                                  '/content/gallery/29b0eaa2b2f1648a871bd1c2b11226b3e20db5d3.jpg'],
#  '/content/query/8eb13e92a2f1b93aea425187e4890c9cdbeada5e.jpg': ['/content/gallery/d8b8e862229b2b3c8d89ba7ec54d2b5a58268fae.jpg',
#                                                                  '/content/gallery/b6e8660776ee0fcfe137af3b44421d1fa236d155.jpg',
#                                                                  '/content/gallery/7e9738e35bda9222fdc76c62885d503e871e0ea6.jpg',
#                                                                  '/content/gallery/53f4cdb4e46bdc2da02f07b1892a820eeedf4ace.jpg',
#                                                                  '/content/gallery/98640ec2ec74181ae77659cafd53f2436d566680.jpg',
#                                                                  '/content/gallery/9208730495d673506b4e99bd89b0a206294cbffc.jpg',
#                                                                  '/content/gallery/e3ff0ab0bf7d26dd0a8cfd79eb03232713889021.jpg',
#                                                                  '/content/gallery/49a8bdab385146363eac9063040f2b519883de83.jpg',
#                                                                  '/content/gallery/cba5174ea4fbc7ff7c95c0f8f129e095acb70581.jpg',
#                                                                  '/content/gallery/b3dee05fad2253037b747e080c29f0b41ac256a0.jpg'],
#  '/content/query/94f69017ee0d1bd74f82f7492103e0845bdd3e58.jpg': ['/content/gallery/20430a8544cc87799abd2c1f79846b0c79eece83.jpg',
#                                                                  '/content/gallery/6da6fc5f7db9564cf3ff726f463cb95844e217d5.jpg',
#                                                                  '/content/gallery/72b6475dba5f69f3d73c8698fac6c9b7773f200c.jpg',
#                                                                  '/content/gallery/92c5b7cc1947358768032bb5389da2e6cee3dcdd.jpg',
#                                                                  '/content/gallery/7e9738e35bda9222fdc76c62885d503e871e0ea6.jpg',
#                                                                  '/content/gallery/31dda3d257e8f948db7690fac308c1e56f4fa01b.jpg',
#                                                                  '/content/gallery/e75754a40e4751c116bf1d319283750414175a94.jpg',
#                                                                  '/content/gallery/d8b8e862229b2b3c8d89ba7ec54d2b5a58268fae.jpg',
#                                                                  '/content/gallery/4abf49518d07fcd17d66b07ce907d0a7c1aaa10a.jpg',
#                                                                  '/content/gallery/dc2ec3366f751b38353f17cdede0788b074dcd23.jpg'],
#  '/content/query/9850240255a078400a9df53e648e9b4017e27fdd.jpg': ['/content/gallery/dde4da4be7dc3e59621180822861722932c428a4.jpg',
#                                                                  '/content/gallery/c072c45860fafdadb4b3bd0e57e7fcbdf278282b.jpg',
#                                                                  '/content/gallery/b3dee05fad2253037b747e080c29f0b41ac256a0.jpg',
#                                                                  '/content/gallery/a4af651a0cba489382b58294b99103da5e30fd75.jpg',
#                                                                  '/content/gallery/dc0d9ed6b4748fd2a649603d3dc649ed4dc143ab.jpg',
#                                                                  '/content/gallery/28c4731c3849cd7e8ac34a303f66689022f29ffe.jpg',
#                                                                  '/content/gallery/209cf5052e344ddbf3b7b42a2165db9aacc0e6a4.jpg',
#                                                                  '/content/gallery/0c318862c14284553f905b835a9cd278f728584e.jpg',
# ...
#                                                                  '/content/gallery/49a8bdab385146363eac9063040f2b519883de83.jpg',
#                                                                  '/content/gallery/612813b2d1214d6f1b63f57a3dfc59a8242e7eb5.jpg'],
#  '/content/query/da58e7edfa325d9f1a60c88a08247794ce37b49f.jpg': ['/content/gallery/72648d7c0c68dd02532c3168a9ebf8ddf84d4c63.jpg',
#                                                                  '/content/gallery/3b19502b113cb02244c07af41605948ea2976c3d.jpg',
#                                                                  '/content/gallery/b6e8660776ee0fcfe137af3b44421d1fa236d155.jpg',
#                                                                  '/content/gallery/967370b8d81249b80975be5ed25b0cc8d9dc793a.jpg',
#                                                                  '/content/gallery/3300db03063be86c6f3f4e3f95dad3b3d56cd6ac.jpg',
#                                                                  '/content/gallery/bc964eea8bccb2d06b633e152b991f5dc64b4ac6.jpg',
#                                                                  '/content/gallery/1389f131b90786a818646879f953ec7b2e886785.jpg',
#                                                                  '/content/gallery/042d993b4def4e932cb7b525ce81d26d81149c40.jpg',
#                                                                  '/content/gallery/b5bee120ca9f126d15b8d2e876019262184e3e0e.jpg',
#                                                                  '/content/gallery/e7d879812455b39cf06fb7c248faab4b63181472.jpg'],
#  '/content/query/dcccd44ff05a07721edfe028687a58d6dd3f9b61.jpg': ['/content/gallery/0c8e251938c98972e6e7401a935e121a07720530.jpg',
#                                                                  '/content/gallery/7b09435486365d34fc5547c2dcd522e9556d39dc.jpg',
#                                                                  '/content/gallery/4780f810c5c866e934bcfce4f22893c2a2719550.jpg',
#                                                                  '/content/gallery/bb5aa39e8472d3628db11aa14b57b027544045aa.jpg',
#                                                                  '/content/gallery/af4205e69426c2c4c20f6be6ed1e6862cf810726.jpg',
#                                                                  '/content/gallery/3cc669950851c2002643511da2918ee4bb2ab08c.jpg',
#                                                                  '/content/gallery/59cf511ee0f3473919c0d41373c37a43e8c40cc4.jpg',
#                                                                  '/content/gallery/b703689c9404bf0cd144d5448b6ac7bdaed246d4.jpg',
#                                                                  '/content/gallery/9c55cbac572d3a5d26d035544d808c14ff04b372.jpg',
#                                                                  '/content/gallery/aaab0cafaf40e73d461698df2747903cb7da39fa.jpg'],
#  '/content/query/dcf8b2e841ada444663339044d7778b7a1466611.jpg': ['/content/gallery/cba3ef3adc680c2f05ff3f4e9dbc9c180b48b6fc.jpg',
#                                                                  '/content/gallery/23fcc8d81233f23b0f798c7c14c87a5f6cb1ceed.jpg',
#                                                                  '/content/gallery/6da6fc5f7db9564cf3ff726f463cb95844e217d5.jpg',
#                                                                  '/content/gallery/4c71701b36ae011ef0cd682ef2054b616b31b908.jpg',
#                                                                  '/content/gallery/9bd8a92a07a46b2a427d4ea0cb8cdbbcbf7c3c86.jpg',
#                                                                  '/content/gallery/3722c591593df5f2271508f1228a14d43041c520.jpg',
#                                                                  '/content/gallery/94970c99f4673dd4d70baba0dd0cd70b6a1b651f.jpg',
#                                                                  '/content/gallery/1cfa965fd2fbb24e734bad2015ebc0533f74722f.jpg',
#                                                                  '/content/gallery/59dcf327925a84c5af3ec8aafa6b1867edde7229.jpg',
#                                                                  '/content/gallery/a6d50a99b0c354b335f38ff29ded0f8affdbd9b0.jpg'],
#  '/content/query/de467d315814ff8c3dcae290e3afe0a84ba898a6.jpg': ['/content/gallery/92d5ba3fa38c3072a90d101ab389fbbaffb0da49.jpg',
#                                                                  '/content/gallery/83f3942d8530abb9f41494458b04bd87692a4963.jpg',
#                                                                  '/content/gallery/c109127c2d00253ff2183a8235452e579d0bb488.jpg',
#                                                                  '/content/gallery/a9f6274756a816ebd4659fd82b2909b55b3eb95c.jpg',
#                                                                  '/content/gallery/f608562e8d1b6ffe7468225b327275dd6ca9e45e.jpg',
#                                                                  '/content/gallery/6557a9f9bd086e58ed7332be5129ff846edcb45b.jpg',
#                                                                  '/content/gallery/11791a86e66ad28bf3d20c99276a103ceafbbb89.jpg',
#                                                                  '/content/gallery/ac609d92beae99229120bcf401f286f69ca6cb87.jpg',
#                                                                  '/content/gallery/cba5174ea4fbc7ff7c95c0f8f129e095acb70581.jpg',
#                                                                  '/content/gallery/108174261a571a6a8e32f20e19f3921027fa2e1e.jpg'],
#  '/content/query/e0c0bc816c1d2e7fe5b7545946d5387fd7247118.jpg': ['/content/gallery/7aa5b6a00cea3370acc1cee120e1a8fcad86a145.jpg',
#                                                                  '/content/gallery/1ddc24fa5b5474f432164b1b5d421a8db732a9bd.jpg',
#                                                                  '/content/gallery/23781683fc5df2f705cd7c68798f6ded30e501b5.jpg',
#                                                                  '/content/gallery/4a4170deb91d9c9d8edf6584952e942ba07463cd.jpg',
#                                                                  '/content/gallery/9ccc53574e27e8bc1add2785969885e4654596bb.jpg',
#                                                                  '/content/gallery/54e646928e751f3d66aa50e48dfbb31e06a3a3e0.jpg',
#                                                                  '/content/gallery/fd2044d3304f9e2f3b2fb870479b7839daa5a268.jpg',
#                                                                  '/content/gallery/3402bde0da3299981dca9085f932ee2312d75289.jpg',
#                                                                  '/content/gallery/886d6a1c544a51d9cd8b741a1e5326a1841ce1c9.jpg',
#                                                                  '/content/gallery/9bf7baa02d2154732fa389e134e7cf0461d43ab8.jpg'],
#  '/content/query/e3c650c4a75eebd95ecf557580832e0e33f14624.jpg': ['/content/gallery/d878abbaeaa8fe560485a10aea819086e4e52709.jpg',
#                                                                  '/content/gallery/13c1f62dfaccdd9b2da09536c39953ecde048305.jpg',
#                                                                  '/content/gallery/cf23d722a7a886cc138ca7d078b9d59da6485371.jpg',
#                                                                  '/content/gallery/e96df30e70fa82e688a577c253471eea4b7ddf49.jpg',
#                                                                  '/content/gallery/dff9eb2318415cfafae4784bb6a60cb79566c252.jpg',
#                                                                  '/content/gallery/7c6d1c7c9ca37fa14ffcb5b63f0edfb8cafa8fe6.jpg',
#                                                                  '/content/gallery/42030db7df093744912709d4b08757e20a3a7bc2.jpg',
#                                                                  '/content/gallery/1bc11614fc3f0bb418f8de4305797efeb26a2070.jpg',
#                                                                  '/content/gallery/af06f2f4711b902c6a29ee92473eabcd12eb56db.jpg',
#                                                                  '/content/gallery/20e2da7c3736d1e434fa10b63a768650e46b28d5.jpg'],
#  '/content/query/e60c4361f7f38a1153bb78db4f5b1c5fc22736ea.jpg': ['/content/gallery/f00632a2a41d0e6c357072fdfcce74db1c8ecb53.jpg',
#                                                                  '/content/gallery/891a185cf4f69c9bafc4ab6a69c662af0384ae82.jpg',
#                                                                  '/content/gallery/3f5477c841680194bf74e4021e2b0c582bbba12a.jpg',
#                                                                  '/content/gallery/a906661f6c0b7ec9ccd9447eaa8f3648b59bd59e.jpg',
#                                                                  '/content/gallery/108174261a571a6a8e32f20e19f3921027fa2e1e.jpg',
#                                                                  '/content/gallery/ae294ea4b121fb89525e06f9498a3692f284f457.jpg',
#                                                                  '/content/gallery/98640ec2ec74181ae77659cafd53f2436d566680.jpg',
#                                                                  '/content/gallery/83f3942d8530abb9f41494458b04bd87692a4963.jpg',
#                                                                  '/content/gallery/be4bab020e9cd519e6994dd577adc9431b2574cb.jpg',
#                                                                  '/content/gallery/c072c45860fafdadb4b3bd0e57e7fcbdf278282b.jpg'],
#  '/content/query/e8d9128f169140a62926a976eb71945eea9d5980.jpg': ['/content/gallery/83a6f0ec567ab08fc70ca7c26e250d4a22cefe90.jpg',
#                                                                  '/content/gallery/acd4ccd2dff1555f08e007451d8f42f8c19f601e.jpg',
#                                                                  '/content/gallery/891a185cf4f69c9bafc4ab6a69c662af0384ae82.jpg',
#                                                                  '/content/gallery/8947be7a0a18c4a3fa233e7c4276eaf424e28fcf.jpg',
#                                                                  '/content/gallery/69c592be98a8aeb73f5fed423e586cac3eab342a.jpg',
#                                                                  '/content/gallery/e7d879812455b39cf06fb7c248faab4b63181472.jpg',
#                                                                  '/content/gallery/42dc322b4985d4da44b86ee5985b511b1b21396c.jpg',
#                                                                  '/content/gallery/16ae1b408b572936aa2a43c1b774b8cb6797abf3.jpg',
#                                                                  '/content/gallery/c6e2f82cf0de7a9386b3ba55adfd61f3637ebe35.jpg',
#                                                                  '/content/gallery/921aa5c9e44b98e309d0c8e98b27cfd440b452dd.jpg'],
#  '/content/query/edc52bcf92c21ad09dd2e7590e65fdeb7d03c897.jpg': ['/content/gallery/ccae2ccb84986c593756c0d8a35557055c42af09.jpg',
#                                                                  '/content/gallery/ddc5a21149b1c1f484da223a357e326e0d93527f.jpg',
#                                                                  '/content/gallery/d85b5ce0b41ee737f57471072527dc0aa63f38cb.jpg',
#                                                                  '/content/gallery/59dcf327925a84c5af3ec8aafa6b1867edde7229.jpg',
#                                                                  '/content/gallery/afefc5537efe71143c6010d195cade8c15aa0e37.jpg',
#                                                                  '/content/gallery/42b241aa67f232343ecb62801db6e4caa3461113.jpg',
#                                                                  '/content/gallery/b3dee05fad2253037b747e080c29f0b41ac256a0.jpg',
#                                                                  '/content/gallery/31dda3d257e8f948db7690fac308c1e56f4fa01b.jpg',
#                                                                  '/content/gallery/ea23315058fb6d35123de00b57d47b9b1cd26283.jpg',
#                                                                  '/content/gallery/19ee0483f60336992299eca3ffeb1d1a889511a3.jpg'],
#  '/content/query/ef8e735bb10d98c254b42d1097f85dc0bddda37b.jpg': ['/content/gallery/b5bee120ca9f126d15b8d2e876019262184e3e0e.jpg',
#                                                                  '/content/gallery/9caadbc33c6bb2bce7345807d6cb09f91a391eaf.jpg',
#                                                                  '/content/gallery/81aa98c4fb413450df484b041b2e88a6f86cd243.jpg',
#                                                                  '/content/gallery/98640ec2ec74181ae77659cafd53f2436d566680.jpg',
#                                                                  '/content/gallery/92d5ba3fa38c3072a90d101ab389fbbaffb0da49.jpg',
#                                                                  '/content/gallery/8f6c9c4afb9eab460be1eb557dc176dc1234e1b8.jpg',
#                                                                  '/content/gallery/cba5174ea4fbc7ff7c95c0f8f129e095acb70581.jpg',
#                                                                  '/content/gallery/eeb5085ffa2c1f2976b0c2af36c22d95af89b5f1.jpg',
#                                                                  '/content/gallery/49a8bdab385146363eac9063040f2b519883de83.jpg',
#                                                                  '/content/gallery/7e9738e35bda9222fdc76c62885d503e871e0ea6.jpg'],
#  '/content/query/f125e3febc11cd5c3da36b6f05814609c0e529a1.jpg': ['/content/gallery/320e7a9d5ae8cb9665fdb464bf9ae6ea39d5e55e.jpg',
#                                                                  '/content/gallery/8f6c9c4afb9eab460be1eb557dc176dc1234e1b8.jpg',
#                                                                  '/content/gallery/df019384c728cd52c9ef057aac9a9f5b51412617.jpg',
#                                                                  '/content/gallery/6f10fdc4b6a290cfa72455c2432c6d0586fdbc40.jpg',
#                                                                  '/content/gallery/b5bee120ca9f126d15b8d2e876019262184e3e0e.jpg',
#                                                                  '/content/gallery/7e5e947f318e282d5cf9b07c6f69b28d79d61253.jpg',
#                                                                  '/content/gallery/7b1563d0025f90b72b979691a04778e82835a4c3.jpg',
#                                                                  '/content/gallery/fa6bb036240952722af17b606851a91df0724f5b.jpg',
#                                                                  '/content/gallery/8252112c7f852bd92c5f2f4da7262889c36f2781.jpg',
#                                                                  '/content/gallery/c88c0f35cb08bfac8be43a53fcc672e2b26a7945.jpg'],
#  '/content/query/f9b0b924d28653db0b8015f99af731f88ce093ef.jpg': ['/content/gallery/ccae2ccb84986c593756c0d8a35557055c42af09.jpg',
#                                                                  '/content/gallery/7e9738e35bda9222fdc76c62885d503e871e0ea6.jpg',
#                                                                  '/content/gallery/75b315a4f3f737984295f9237405f7a4f51b9698.jpg',
#                                                                  '/content/gallery/120365695a5080e6b4643bea93bb0d5acf15f98c.jpg',
#                                                                  '/content/gallery/2f4ae1c1d785c8f893be2d444fbf682f43c5e182.jpg',
#                                                                  '/content/gallery/cf397e1b4bee177da0d26c3ada17713b37e18afd.jpg',
#                                                                  '/content/gallery/b3dee05fad2253037b747e080c29f0b41ac256a0.jpg',
#                                                                  '/content/gallery/f4c5c759fde7c2caaa63c05cc1cfa5afb3333931.jpg',
#                                                                  '/content/gallery/cc9a8f271a5839819f797ee73464aaa16ee4dfec.jpg',
#                                                                  '/content/gallery/c109127c2d00253ff2183a8235452e579d0bb488.jpg']}

# %%
plt.imshow(plt.imread('/content/query/013c80f43deff8d61b6a2021f9b0a335665fdd1f.jpg'))
plt.show()
print('\n\n')

for similar_image in dizionario['/content/query/013c80f43deff8d61b6a2021f9b0a335665fdd1f.jpg']:
  plt.imshow(plt.imread(similar_image))
  plt.show()
  print('\n\n')
